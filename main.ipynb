# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("NNdataset.csv")
df
# Out:
#               datetime             city    lat   lon  temp  humidity  \
# 0     2025-11-18T00:00  Nizhny Novgorod  56.33  44.0   3.5        95
# 1     2025-11-18T01:00  Nizhny Novgorod  56.33  44.0   3.9        95
# 2     2025-11-18T02:00  Nizhny Novgorod  56.33  44.0   4.0        96
# 3     2025-11-18T03:00  Nizhny Novgorod  56.33  44.0   3.7        96
# 4     2025-11-18T04:00  Nizhny Novgorod  56.33  44.0   3.7        97
# ...                ...              ...    ...   ...   ...       ...
# 2179  2026-02-16T19:00  Nizhny Novgorod  56.33  44.0 -10.6        82
# 2180  2026-02-16T20:00  Nizhny Novgorod  56.33  44.0 -10.6        82
# 2181  2026-02-16T21:00  Nizhny Novgorod  56.33  44.0 -10.6        82
# 2182  2026-02-16T22:00  Nizhny Novgorod  56.33  44.0 -10.4        82
# 2183  2026-02-16T23:00  Nizhny Novgorod  56.33  44.0 -10.2        82
#
#       pressure  wind_speed  wind_dir  precipitation  cloud_cover  visibility  \
# ...

# %%
print(df["visibility"].isna().sum())
# Out:
# 2184
